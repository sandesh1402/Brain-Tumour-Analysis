# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk('D:/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk("D:/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 30s 4s/step - loss: 31.0133 - val_loss: 86.7015
# Epoch 2/30
# 3/3 [==============================] - 8s 3s/step - loss: 37.6381 - val_loss: 20.6202
# Epoch 3/30
# 3/3 [==============================] - 7s 3s/step - loss: 6.7360 - val_loss: 55.5356
# Epoch 4/30
# 3/3 [==============================] - 7s 3s/step - loss: 9.4633 - val_loss: 20.8422
# Epoch 5/30
# 3/3 [==============================] - 7s 2s/step - loss: 2.4711 - val_loss: 11.7764
# Epoch 6/30
# 3/3 [==============================] - 7s 3s/step - loss: 1.6815 - val_loss: 12.8663
# Epoch 7/30
# 3/3 [==============================] - 7s 3s/step - loss: 1.2106 - val_loss: 9.3131
# Epoch 8/30
# 3/3 [==============================] - 7s 2s/step - loss: 0.7720 - val_loss: 8.8221
# Epoch 9/30
# 3/3 [==============================] - 7s 2s/step - loss: 1.1504 - val_loss: 8.3820
# Epoch 10/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.3294 - val_loss: 8.3745
# Epoch 11/30
# 3/3 [==============================] - 7s 3s/step - loss: 0.4426 - val_loss: 8.0530
# Epoch 12/30
# 3/3 [==============================] - 7s 3s/step - loss: 0.2798 - val_loss: 8.2455
# Epoch 13/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.1566 - val_loss: 8.3821
# Epoch 14/30
# 3/3 [==============================] - 10s 4s/step - loss: 0.3462 - val_loss: 7.8585
# Epoch 15/30
# 3/3 [==============================] - 9s 4s/step - loss: 0.1090 - val_loss: 7.3134
# Epoch 16/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0886 - val_loss: 6.9052
# Epoch 17/30
# 3/3 [==============================] - 10s 3s/step - loss: 0.0591 - val_loss: 6.6841
# Epoch 18/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0164 - val_loss: 6.4270
# Epoch 19/30
# 3/3 [==============================] - 9s 3s/step - loss: 1.2545e-05 - val_loss: 6.1774
# Epoch 20/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.1809 - val_loss: 5.6390
# Epoch 21/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0024 - val_loss: 5.2918
# Epoch 22/30
# 3/3 [==============================] - 10s 4s/step - loss: 0.0861 - val_loss: 5.0916
# Epoch 23/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0480 - val_loss: 5.0421
# Epoch 24/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0681 - val_loss: 5.1761
# Epoch 25/30
# 3/3 [==============================] - 9s 3s/step - loss: 2.6029e-04 - val_loss: 5.3448
# Epoch 26/30
# 3/3 [==============================] - 8s 3s/step - loss: 0.0016 - val_loss: 5.4648
# Epoch 27/30
# 3/3 [==============================] - 9s 3s/step - loss: 1.8498e-04 - val_loss: 5.5318
# Epoch 28/30
# 3/3 [==============================] - 9s 3s/step - loss: 0.0815 - val_loss: 5.4753
# Epoch 29/30
# 3/3 [==============================] - 9s 3s/step - loss: 7.8100e-04 - val_loss: 5.3854
# Epoch 30/30
# 3/3 [==============================] - 7s 3s/step - loss: 0.0038 - val_loss: 5.2571

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open("D:/brain_tumor_dataset/no/2 no.jpeg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open("D:/brain_tumor_dataset/yes/Y2.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 99.2966890335083% Confidence This Is A No, Its not a tumor

# %% [markdown]
# Thats It's
